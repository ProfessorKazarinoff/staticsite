# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0.001,4,0.001)
y1 = np.log(x)
y2 = np.exp(x)

# %%
fig, ax = plt.subplots()

plt.style.use('tableau-colorblind10')

ax.plot(x,y1,x,y2)
ax.legend(['ln(x)','exp(x)'])
fig.savefig('exp-log-plot.png')
plt.show()

# %%
for style in plt.style.available:
    print(style)
# Out:
# Solarize_Light2
# _classic_test_patch
# _mpl-gallery
# _mpl-gallery-nogrid
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
fig = plt.figure(dpi=100, figsize=(10, 20), tight_layout=True)
available = ['default'] + plt.style.available
for i, style in enumerate(available):
    with plt.style.context(style):
        ax = fig.add_subplot(10, 3, i + 1)
        ax.plot(x,y1,x,y2)
    ax.set_title(style)
plt.show()
