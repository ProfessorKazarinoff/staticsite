# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping
import numpy as np
# %matplotlib inline

from skimage import color
from skimage import data
img = data.astronaut()
img_hsv = color.rgb2hsv(img)

# %%
img = mping.imread('red_dots.JPG')
img_plot = plt.imshow(img_out)

# %%
hsv = color.rgb2hsv(img)
#%matplotlib qt
plt.imshow(hsv)

# %%
h = hsv[:,:,0]

# %%
size(h)

# %%
reddish = img_out[:,:,0] > 160
img_out[reddish] = [0,255,0]
plt.imshow(img_out)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3aed5d46e0b1> in <module>()
#       1 reddish = img_out[:,:,0] > 160
# ----> 2 img_out[reddish] = [0,255,0]
#       3 plt.imshow(img_out)
#
# ValueError: assignment destination is read-only

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
plt.imshow(img_hsv)

# %%
type(img_hsv)
# Out:
# numpy.ndarray

# %%
shape(img_hsv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-94c4bda7e2cc> in <module>()
# ----> 1 shape(img_hsv)
#
# NameError: name 'shape' is not defined

# %%
img_hsv.size
# Out:
# 786432

# %%
img_hsv.shape
# Out:
# (512, 512, 3)

# %%
img_hsv[1][1]
# Out:
# array([ 0.88888889,  0.02083333,  0.56470588])
