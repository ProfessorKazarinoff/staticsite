# %% [markdown]
# This is the juypter notebook post

# %%
#Some code for the post
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [1,3,5,7,9,12,13,15]
plt.plot(data)

# %% [markdown]
# $\frac{num}{denom^2}$
