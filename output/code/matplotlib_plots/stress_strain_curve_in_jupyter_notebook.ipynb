# %% [markdown]
# Plotting stress strain curves is a useful skill in mechanical engineering because it allows us to derive mechanical properties of materials such as tensile strength, elastic modulus, yield strength and ductility. Plotting stress strain curves can be accomplished with Excel and MATLAB, but what about plotting stress strain curves with Python? Follow along to find out.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfa=pd.read_excel('Al_6061.xls')
dfa.tail(20)
# Out:
#      TESTNUM  POINTNUM     TIME    POSIT        FORCE       EXT        CH5  \
# 215      703       216  128.178  0.66062  8206.192383  3.003093 -44.494556
# 216      703       217  128.483  0.66296  8155.396973  3.003093 -44.382210
# 217      703       218  128.777  0.66528  8104.094727  3.003093 -44.325550
# 218      703       219  129.176  0.66836  8036.070312  3.003093 -44.268997
# 219      703       220  129.380  0.67068  7985.527344  3.003093 -44.215889
# 220      703       221  129.677  0.67302  7930.422852  3.003093 -44.162060
# 221      703       222  129.977  0.67532  7877.725098  3.003093 -44.101597
# 222      703       223  130.279  0.67764  7825.786621  3.003093 -44.051384
# 223      703       224  130.476  0.67996  7766.627441  3.003093 -43.997040
# 224      703       225  130.778  0.68226  7711.141113  3.003093 -43.941296
# 225      703       226  131.080  0.68460  7653.880859  3.003093 -43.880756
# 226      703       227  131.380  0.68692  7598.014160  3.003093 -43.821201
# 227      703       228  131.680  0.68924  7537.712402  3.003093 -43.770218
# 228      703       229  131.878  0.69154  7478.296875  3.003093 -43.713715
# 229      703       230  132.177  0.69384  7416.094238  3.003093 -43.654919
# 230      703       231  132.479  0.69618  7352.496582  3.003093 -43.604691
# 231      703       232  132.779  0.69850  7286.491699  3.003093 -43.486691
# 232      703       233  132.979  0.70082  7219.219238  3.003093 -43.486691
# 233      703       234  133.178  0.70236  7169.176270  3.003093 -43.428616
# 234      703       235  133.178  0.70236  7169.176270  3.003093 -43.428616
#
#      CH6  CH7  CH8
# 215  NaN  NaN  NaN
# 216  NaN  NaN  NaN
# 217  NaN  NaN  NaN
# 218  NaN  NaN  NaN
# 219  NaN  NaN  NaN
# 220  NaN  NaN  NaN
# 221  NaN  NaN  NaN
# 222  NaN  NaN  NaN
# 223  NaN  NaN  NaN
# 224  NaN  NaN  NaN
# 225  NaN  NaN  NaN
# 226  NaN  NaN  NaN
# 227  NaN  NaN  NaN
# 228  NaN  NaN  NaN
# 229  NaN  NaN  NaN
# 230  NaN  NaN  NaN
# 231  NaN  NaN  NaN
# 232  NaN  NaN  NaN
# 233  NaN  NaN  NaN
# 234  NaN  NaN  NaN

# %%
d=0.506
A0 = np.pi*(d/2)**2
stress_Al = dfa['FORCE'][1:166]
strain_Al = dfa['EXT'][1:166]

l0 = 2.0
lf = 2.24
strain_Al_f = (lf-l0)/l0

x_al = []

# %%
plt.plot(strain_Al, stress_Al)
plt.show()
