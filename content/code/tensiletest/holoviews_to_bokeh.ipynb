# %%
import pandas as pd

df = pd.read_csv('stress_strain_data.csv', sep=',', header=None, skiprows=0)
df.columns = ['strain', 'stress']

holoviews_curve = hv.Curve(df)

renderer = hv.renderer('bokeh')

# Convert to bokeh figure then save using bokeh
bokeh_plot = renderer.get_plot(holoviews_curve).state

from bokeh.io import output_file, show
output_file("bokeh_plot_from_holoviews.html")
show(bokeh_plot)

from IPython.core.display import HTML
HTML("bokeh_plot_from_holoviews.html")
# Out:
# INFO:bokeh.io.state:Session output file 'bokeh_plot_from_holoviews.html' already exists, will be overwritten.
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>Bokeh Plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.13.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="bk-plotdiv" id="a9af030d-cff3-4e77-9abc-fbcbd9a9fe27"></div>
#         </div>
#
#         <script type="application/json" id="50f75242-5f8a-4b0d-a1fd-6383b233dde0">
#           {"ca6f6fa5-5648-4737-b4bb-1bc8a0a94f4b":{"roots":{"references":[{"attributes":{},"id":"17fd53b2-d72d-4dfb-8fe9-eb5fd500eaec","type":"WheelZoomTool"},{"attributes":{},"id":"2fe24a38-5b38-4092-85af-23b400728b77","type":"PanTool"},{"attributes":{"line_alpha":0.1,"line_color":"#30a2da","line_width":2,"x":{"field":"strain"},"y":{"field":"stress"}},"id":"26215eee-4bb6-474e-bdb3-2df1e9b19385","type":"Line"},{"attributes":{},"id":"339f5e0a-b9ae-4e68-ba01-389dc22d6f86","type":"BasicTicker"},{"attributes":{"source":{"id":"b1fb26c0-97e6-42a5-8862-2809d02fd58f","type":"ColumnDataSource"}},"id":"a79f36fa-4e23-4d30-804d-fa4db491c2a6","type":"CDSView"},{"attributes":{"axis_label":"strain","bounds":"auto","formatter":{"id":"fdeb4af0-537a-4094-b2bc-cb1b8dfbc61a","type":"BasicTickFormatter"},"major_label_orientation":"horizontal","plot":{"id":"ec406471-115d-4713-ae6e-7f4ce2f9738f","subtype":"Figure","type":"Plot"},"ticker":{"id":"8d866941-de50-41ae-a758-308417e258ca","type":"BasicTicker"}},"id":"d03b0f88-bf71-45dd-ab5c-b149d0ab0352","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["strain","stress"],"data":{"strain":{"__ndarray__":"...","dtype":"float64","shape":[73]},"stress":{"__ndarray__":"...","dtype":"float64","shape":[73]}}},"id":"3a6eb609-aeb4-4d7c-93b3-decc128008d8","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":0.14681},"id":"49803b06-3c40-4bb6-9306-12ac9d20e251","type":"Range1d